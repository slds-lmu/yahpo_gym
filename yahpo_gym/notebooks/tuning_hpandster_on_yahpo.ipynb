# %% [markdown]
# ## Tuning YAHPO using `HPBandSter`
#
# In order to demonstrate using YAHPO Gym more in-depth we provide a full example benchmarking `HPBandSter` on an `lcbench` task.
#
# Note, that this requires the `hpbandster` module to be installed.
#
# We again start by importing the relevant modules:

# %%
from yahpo_gym import *
import time
import numpy as np

# %% [markdown]
# First, we define a worker class as required by `HPBandSter` that internally calls our `objective_function`.

# %%
from hpbandster.core.worker import Worker
import hpbandster.core.nameserver as hpns
from hpbandster.optimizers import BOHB as BOHB

class lcbench(Worker):

    def __init__(self, *args, sleep_interval=0, **kwargs):
        super().__init__(*args, **kwargs)
        self.bench = bench
        self.sleep_interval = sleep_interval

    def compute(self, config, budget, **kwargs):
        """
        Args:
            config: dictionary containing the sampled configurations by the optimizer
            budget: (float) amount of epochs the model can use to train

        Returns:
            dictionary with mandatory fields:
                "loss" (scalar)
                "info" (dict)
        """

        config.update({"epoch": int(np.round(budget))})  # update epoch
        result = bench.objective_function(config)  # evaluate

        time.sleep(self.sleep_interval)

        return({
                    "loss": - float(result[0].get("val_accuracy")),  # we want to maximize validation accuracy
                    "info": "empty"
                })
    
    @staticmethod
    def get_configspace():
        # remove the epoch fidelity parameter for HPBandSter
        cs = bench.get_opt_space(drop_fidelity_params = True)
        return(cs)

# %% [markdown]
# Using this worker class, we can now run the full benchmark:

# %%
# Initialize the set providing a scenario
bench = benchmark_set.BenchmarkSet("lcbench", instance = "3945")

# Start up the nameserver
NS = hpns.NameServer(run_id="lcbench", host="127.0.0.1", port=None)
NS.start()

# Run BOHB
w = lcbench(sleep_interval=0, nameserver="127.0.0.1", run_id ="lcbench")
w.run(background=True)

bohb = BOHB(configspace=w.get_configspace(),
            run_id="lcbench", nameserver="127.0.0.1",
            min_budget=1, max_budget=52)

res = bohb.run(n_iterations=1)

bohb.shutdown(shutdown_workers=True)
NS.shutdown()
# Out:
# 20:49:35 wait_for_workers trying to get the condition
# 20:49:35 WORKER: Connected to nameserver <Pyro4.core.Proxy at 0x7f4e9db91af0; connected IPv4; for PYRO:Pyro.NameServer@127.0.0.1:9090>
# 20:49:35 DISPATCHER: started the 'discover_worker' thread
# 20:49:35 WORKER: No dispatcher found. Waiting for one to initiate contact.
# 20:49:35 WORKER: start listening for jobs
# 20:49:35 DISPATCHER: started the 'job_runner' thread
# 20:49:35 DISPATCHER: Pyro daemon running on localhost:43081
# 20:49:35 DISPATCHER: Starting worker discovery
# 20:49:35 DISPATCHER: Found 1 potential workers, 0 currently in the pool.
# 20:49:35 DISPATCHER: discovered new worker, hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 HBMASTER: number of workers changed to 1
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 HBMASTER: only 1 worker(s) available, waiting for at least 1.
# 20:49:35 adjust_queue_size: lock accquired
# 20:49:35 HBMASTER: adjusted queue size to (0, 1)
# 20:49:35 DISPATCHER: Finished worker discovery
# 20:49:35 DISPATCHER: A new worker triggered discover_worker
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Enough workers to start this run!
# 20:49:35 DISPATCHER: Starting worker discovery
# 20:49:35 HBMASTER: starting run at 1645127375.206001
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 20:49:35 HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 0) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 0)
# 20:49:35 DISPATCHER: Finished worker discovery
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 0) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 0) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: start processing job (0, 0, 0)
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 475, 'learning_rate': 0.000279421845934996, 'max_dropout': 0.23277220802293364, 'max_units': 564.7617170743333, 'momentum': 0.28984493464511285, 'num_layers': 3, 'weight_decay': 0.08149013793334492}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 0), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 0) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 0) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 0) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 0)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 475, 'learning_rate': 0.000279421845934996, 'max_dropout': 0.23277220802293364, 'max_units': 564.7617170743333, 'momentum': 0.28984493464511285, 'num_layers': 3, 'weight_decay': 0.08149013793334492}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -48.53059005737305, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 0) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 0) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Only 1 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 0) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 1) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 1)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 1) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 1) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 1)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 56, 'learning_rate': 0.006354512231197386, 'max_dropout': 0.53899351576789, 'max_units': 760.0387687665543, 'momentum': 0.9524552152326227, 'num_layers': 1, 'weight_decay': 0.014299983728636233}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 1), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 1) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 1) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 1) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 1)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 56, 'learning_rate': 0.006354512231197386, 'max_dropout': 0.53899351576789, 'max_units': 760.0387687665543, 'momentum': 0.9524552152326227, 'num_layers': 1, 'weight_decay': 0.014299983728636233}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -76.36394500732422, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 1) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 1) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Only 2 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 1) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 2) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 2)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 2) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 2) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 2)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 470, 'learning_rate': 0.054473558440077924, 'max_dropout': 0.7775565406704537, 'max_units': 877.9389562040402, 'momentum': 0.20871034235326025, 'num_layers': 1, 'weight_decay': 0.09301422668185681}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 2), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 2) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 2) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 2) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 2)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 470, 'learning_rate': 0.054473558440077924, 'max_dropout': 0.7775565406704537, 'max_units': 877.9389562040402, 'momentum': 0.20871034235326025, 'num_layers': 1, 'weight_decay': 0.09301422668185681}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -59.2815055847168, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 2) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 2) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Only 3 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 2) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 3) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 3) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 3)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 3) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 3) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 3) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: start processing job (0, 0, 3)
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 107, 'learning_rate': 0.0008056685300095102, 'max_dropout': 0.6274292282744589, 'max_units': 313.29716079334656, 'momentum': 0.9547624615852874, 'num_layers': 4, 'weight_decay': 0.06927593294123785}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 3), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 3) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 3) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 3) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 3)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 107, 'learning_rate': 0.0008056685300095102, 'max_dropout': 0.6274292282744589, 'max_units': 313.29716079334656, 'momentum': 0.9547624615852874, 'num_layers': 4, 'weight_decay': 0.06927593294123785}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -78.34871673583984, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 3) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 3) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Only 4 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 3) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 4) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 4) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 4)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 4) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 4) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 4) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 4)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 107, 'learning_rate': 0.023759716613041697, 'max_dropout': 0.48796545419258286, 'max_units': 1015.3394832852503, 'momentum': 0.21920889883414185, 'num_layers': 3, 'weight_decay': 0.07525760547087604}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 4), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 4) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 4) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 4) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 4)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 107, 'learning_rate': 0.023759716613041697, 'max_dropout': 0.48796545419258286, 'max_units': 1015.3394832852503, 'momentum': 0.21920889883414185, 'num_layers': 3, 'weight_decay': 0.07525760547087604}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -82.80667114257812, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 4) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 4) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Only 5 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 4) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 5) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 5) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 5)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 5) submitted to dispatcher
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 DISPATCHER: starting job (0, 0, 5) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 5) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 5)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 38, 'learning_rate': 0.02740096278714067, 'max_dropout': 0.3117686181947872, 'max_units': 85.93326642988048, 'momentum': 0.91203473173557, 'num_layers': 1, 'weight_decay': 0.009653138036987183}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 5), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 5) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 5) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 5) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 5)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 38, 'learning_rate': 0.02740096278714067, 'max_dropout': 0.3117686181947872, 'max_units': 85.93326642988048, 'momentum': 0.91203473173557, 'num_layers': 1, 'weight_decay': 0.009653138036987183}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -80.75731658935547, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 5) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 5) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Only 6 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 5) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 6) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 6) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 6)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 6) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 6) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 6) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 6)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 178, 'learning_rate': 0.0036082742387284566, 'max_dropout': 0.8683862619706104, 'max_units': 73.30774499129984, 'momentum': 0.61144320171166, 'num_layers': 2, 'weight_decay': 0.03665315022053044}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 6), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 6) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 6) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 6) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 6)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 178, 'learning_rate': 0.0036082742387284566, 'max_dropout': 0.8683862619706104, 'max_units': 73.30774499129984, 'momentum': 0.61144320171166, 'num_layers': 2, 'weight_decay': 0.03665315022053044}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -65.7552490234375, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 6) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 6) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 Only 7 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 6) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 7) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 7) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 7)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 7) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 7) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 7) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 7)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 37, 'learning_rate': 0.0017057941756880518, 'max_dropout': 0.2944339409301566, 'max_units': 789.224718474469, 'momentum': 0.2512190464451524, 'num_layers': 2, 'weight_decay': 0.03696088552919684}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 7), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 7) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 7) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 7) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 7)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 37, 'learning_rate': 0.0017057941756880518, 'max_dropout': 0.2944339409301566, 'max_units': 789.224718474469, 'momentum': 0.2512190464451524, 'num_layers': 2, 'weight_decay': 0.03696088552919684}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -81.92047882080078, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 7) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 job_callback for (0, 0, 7) got condition
# 20:49:35 Only 8 run(s) for budget 1.925926 available, need more than 10 -> can't build model!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 7) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 8) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 8) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 8)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 8) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 8) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 8) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 8)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 60, 'learning_rate': 0.001476187203077695, 'max_dropout': 0.8410221316682499, 'max_units': 76.66865411198056, 'momentum': 0.5198854203560104, 'num_layers': 4, 'weight_decay': 0.06073803972957833}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 8), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 8) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 8) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 8) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 8)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 60, 'learning_rate': 0.001476187203077695, 'max_dropout': 0.8410221316682499, 'max_units': 76.66865411198056, 'momentum': 0.5198854203560104, 'num_layers': 4, 'weight_decay': 0.06073803972957833}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -81.11315155029297, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 8) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 8) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 8) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 9) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 9) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 9)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 9) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 9) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 9) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 9)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 32, 'learning_rate': 0.002214603706032655, 'max_dropout': 0.5086992057264205, 'max_units': 88.57850791827076, 'momentum': 0.6403074434260884, 'num_layers': 5, 'weight_decay': 0.012816561379753523}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 9), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 9) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 9) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 9) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 9)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 32, 'learning_rate': 0.002214603706032655, 'max_dropout': 0.5086992057264205, 'max_units': 88.57850791827076, 'momentum': 0.6403074434260884, 'num_layers': 5, 'weight_decay': 0.012816561379753523}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -88.0889663696289, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 9) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 9) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 9) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 10) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 10) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 10)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 10) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 10) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 10) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 10)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 177, 'learning_rate': 0.057437511966709674, 'max_dropout': 0.22954115201665692, 'max_units': 904.4787930506377, 'momentum': 0.2644376325733805, 'num_layers': 3, 'weight_decay': 0.03920370604017777}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 10), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 10) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 10) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 10) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 10)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 177, 'learning_rate': 0.057437511966709674, 'max_dropout': 0.22954115201665692, 'max_units': 904.4787930506377, 'momentum': 0.2644376325733805, 'num_layers': 3, 'weight_decay': 0.03920370604017777}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -81.21027374267578, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 10) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 10) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 10) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 11) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 11) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 11)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 11) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 11) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 11) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: start processing job (0, 0, 11)
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 47, 'learning_rate': 0.0015700567569372414, 'max_dropout': 0.8581368374164389, 'max_units': 88.90522272429436, 'momentum': 0.6549488289926071, 'num_layers': 4, 'weight_decay': 0.013022608179727954}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 11), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 11) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 11) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 11) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 11)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 47, 'learning_rate': 0.0015700567569372414, 'max_dropout': 0.8581368374164389, 'max_units': 88.90522272429436, 'momentum': 0.6549488289926071, 'num_layers': 4, 'weight_decay': 0.013022608179727954}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -84.83544158935547, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 11) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 11) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 11) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 12) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 12) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 12)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 12) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 12) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 12) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 12)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 61, 'learning_rate': 0.0015064272555883043, 'max_dropout': 0.6323022686449326, 'max_units': 674.6319986695589, 'momentum': 0.7910702281500807, 'num_layers': 1, 'weight_decay': 0.04951487195483898}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 12), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 12) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 12) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 12) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 12)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 61, 'learning_rate': 0.0015064272555883043, 'max_dropout': 0.6323022686449326, 'max_units': 674.6319986695589, 'momentum': 0.7910702281500807, 'num_layers': 1, 'weight_decay': 0.04951487195483898}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -70.72581481933594, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 12) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 12) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 12) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 13) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 13) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 13)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 13) submitted to dispatcher
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: starting job (0, 0, 13) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 13) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 13)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 512, 'learning_rate': 0.0016498091380771458, 'max_dropout': 0.5396042938049899, 'max_units': 84.91367883532084, 'momentum': 0.35399083498210604, 'num_layers': 4, 'weight_decay': 0.09480577382148775}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:35 WORKER: done with job (0, 0, 13), trying to register it.
# 20:49:35 WORKER: registered result for job (0, 0, 13) with dispatcher
# 20:49:35 DISPATCHER: job (0, 0, 13) finished
# 20:49:35 DISPATCHER: register_result: lock acquired
# 20:49:35 DISPATCHER: job (0, 0, 13) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:35 job_id: (0, 0, 13)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 512, 'learning_rate': 0.0016498091380771458, 'max_dropout': 0.5396042938049899, 'max_units': 84.91367883532084, 'momentum': 0.35399083498210604, 'num_layers': 4, 'weight_decay': 0.09480577382148775}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -54.081886291503906, 'info': 'empty'}
# exception: None
#
# 20:49:35 job_callback for (0, 0, 13) started
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 job_callback for (0, 0, 13) got condition
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:35 HBMASTER: Trying to run another job!
# 20:49:35 job_callback for (0, 0, 13) finished
# 20:49:35 start sampling a new configuration.
# 20:49:35 done sampling a new configuration.
# 20:49:35 HBMASTER: schedule new run for iteration 0
# 20:49:35 HBMASTER: trying submitting job (0, 0, 14) to dispatcher
# 20:49:35 HBMASTER: submitting job (0, 0, 14) to dispatcher
# 20:49:35 DISPATCHER: trying to submit job (0, 0, 14)
# 20:49:35 DISPATCHER: trying to notify the job_runner thread.
# 20:49:35 HBMASTER: job (0, 0, 14) submitted to dispatcher
# 20:49:35 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:35 DISPATCHER: Trying to submit another job.
# 20:49:35 DISPATCHER: starting job (0, 0, 14) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 DISPATCHER: job (0, 0, 14) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:35 WORKER: start processing job (0, 0, 14)
# 20:49:35 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:35 WORKER: args: ()
# 20:49:35 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 110, 'learning_rate': 0.03156520213590733, 'max_dropout': 0.15672883032679918, 'max_units': 281.31927448719534, 'momentum': 0.7125991123090649, 'num_layers': 1, 'weight_decay': 0.08829546149767076}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:36 WORKER: done with job (0, 0, 14), trying to register it.
# 20:49:36 WORKER: registered result for job (0, 0, 14) with dispatcher
# 20:49:36 DISPATCHER: job (0, 0, 14) finished
# 20:49:36 DISPATCHER: register_result: lock acquired
# 20:49:36 DISPATCHER: job (0, 0, 14) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:36 job_id: (0, 0, 14)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 110, 'learning_rate': 0.03156520213590733, 'max_dropout': 0.15672883032679918, 'max_units': 281.31927448719534, 'momentum': 0.7125991123090649, 'num_layers': 1, 'weight_decay': 0.08829546149767076}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -68.1801528930664, 'info': 'empty'}
# exception: None
#
# 20:49:36 job_callback for (0, 0, 14) started
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 job_callback for (0, 0, 14) got condition
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:36 HBMASTER: Trying to run another job!
# 20:49:36 job_callback for (0, 0, 14) finished
# 20:49:36 start sampling a new configuration.
# 20:49:36 done sampling a new configuration.
# 20:49:36 HBMASTER: schedule new run for iteration 0
# 20:49:36 HBMASTER: trying submitting job (0, 0, 15) to dispatcher
# 20:49:36 HBMASTER: submitting job (0, 0, 15) to dispatcher
# 20:49:36 DISPATCHER: trying to submit job (0, 0, 15)
# 20:49:36 DISPATCHER: trying to notify the job_runner thread.
# 20:49:36 HBMASTER: job (0, 0, 15) submitted to dispatcher
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:36 DISPATCHER: starting job (0, 0, 15) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 DISPATCHER: job (0, 0, 15) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 WORKER: start processing job (0, 0, 15)
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:36 WORKER: args: ()
# 20:49:36 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 316, 'learning_rate': 0.00033084169555737527, 'max_dropout': 0.36527654834607304, 'max_units': 290.8730954226177, 'momentum': 0.5470828298850363, 'num_layers': 1, 'weight_decay': 0.09440025839674766}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:36 WORKER: done with job (0, 0, 15), trying to register it.
# 20:49:36 WORKER: registered result for job (0, 0, 15) with dispatcher
# 20:49:36 DISPATCHER: job (0, 0, 15) finished
# 20:49:36 DISPATCHER: register_result: lock acquired
# 20:49:36 DISPATCHER: job (0, 0, 15) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:36 job_id: (0, 0, 15)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 316, 'learning_rate': 0.00033084169555737527, 'max_dropout': 0.36527654834607304, 'max_units': 290.8730954226177, 'momentum': 0.5470828298850363, 'num_layers': 1, 'weight_decay': 0.09440025839674766}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -50.153682708740234, 'info': 'empty'}
# exception: None
#
# 20:49:36 job_callback for (0, 0, 15) started
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 job_callback for (0, 0, 15) got condition
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:36 HBMASTER: Trying to run another job!
# 20:49:36 job_callback for (0, 0, 15) finished
# 20:49:36 start sampling a new configuration.
# 20:49:36 done sampling a new configuration.
# 20:49:36 HBMASTER: schedule new run for iteration 0
# 20:49:36 HBMASTER: trying submitting job (0, 0, 16) to dispatcher
# 20:49:36 HBMASTER: submitting job (0, 0, 16) to dispatcher
# 20:49:36 DISPATCHER: trying to submit job (0, 0, 16)
# 20:49:36 DISPATCHER: trying to notify the job_runner thread.
# 20:49:36 HBMASTER: job (0, 0, 16) submitted to dispatcher
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:36 DISPATCHER: starting job (0, 0, 16) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 DISPATCHER: job (0, 0, 16) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 WORKER: start processing job (0, 0, 16)
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:36 WORKER: args: ()
# 20:49:36 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.0621136801775151, 'max_dropout': 0.6721466528329146, 'max_units': 821.9641742662092, 'momentum': 0.6493487959873308, 'num_layers': 5, 'weight_decay': 0.04679336780314606}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:36 WORKER: done with job (0, 0, 16), trying to register it.
# 20:49:36 WORKER: registered result for job (0, 0, 16) with dispatcher
# 20:49:36 DISPATCHER: job (0, 0, 16) finished
# 20:49:36 DISPATCHER: register_result: lock acquired
# 20:49:36 DISPATCHER: job (0, 0, 16) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:36 job_id: (0, 0, 16)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.0621136801775151, 'max_dropout': 0.6721466528329146, 'max_units': 821.9641742662092, 'momentum': 0.6493487959873308, 'num_layers': 5, 'weight_decay': 0.04679336780314606}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -90.24736785888672, 'info': 'empty'}
# exception: None
#
# 20:49:36 job_callback for (0, 0, 16) started
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 job_callback for (0, 0, 16) got condition
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:36 HBMASTER: Trying to run another job!
# 20:49:36 job_callback for (0, 0, 16) finished
# 20:49:36 start sampling a new configuration.
# 20:49:36 done sampling a new configuration.
# 20:49:36 HBMASTER: schedule new run for iteration 0
# 20:49:36 HBMASTER: trying submitting job (0, 0, 17) to dispatcher
# 20:49:36 HBMASTER: submitting job (0, 0, 17) to dispatcher
# 20:49:36 DISPATCHER: trying to submit job (0, 0, 17)
# 20:49:36 DISPATCHER: trying to notify the job_runner thread.
# 20:49:36 HBMASTER: job (0, 0, 17) submitted to dispatcher
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:36 DISPATCHER: starting job (0, 0, 17) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 DISPATCHER: job (0, 0, 17) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 WORKER: start processing job (0, 0, 17)
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:36 WORKER: args: ()
# 20:49:36 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.02900417954390053, 'max_dropout': 0.5570228883121834, 'max_units': 470.78713650589003, 'momentum': 0.29739682673947965, 'num_layers': 1, 'weight_decay': 0.024829031497879243}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:36 WORKER: done with job (0, 0, 17), trying to register it.
# 20:49:36 WORKER: registered result for job (0, 0, 17) with dispatcher
# 20:49:36 DISPATCHER: job (0, 0, 17) finished
# 20:49:36 DISPATCHER: register_result: lock acquired
# 20:49:36 DISPATCHER: job (0, 0, 17) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:36 job_id: (0, 0, 17)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.02900417954390053, 'max_dropout': 0.5570228883121834, 'max_units': 470.78713650589003, 'momentum': 0.29739682673947965, 'num_layers': 1, 'weight_decay': 0.024829031497879243}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -83.31269073486328, 'info': 'empty'}
# exception: None
#
# 20:49:36 job_callback for (0, 0, 17) started
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 job_callback for (0, 0, 17) got condition
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:36 done building a new model for budget 1.925926 based on 9/15 split
# Best loss for this budget:-90.247368
#
#
#
#
#
# 20:49:36 HBMASTER: Trying to run another job!
# 20:49:36 job_callback for (0, 0, 17) finished
# 20:49:36 start sampling a new configuration.
# 20:49:36 best_vector: [0.0022691153972895332, 0.49191701236664376, 0.5861770694032492, 0.0025711697433429825, 0.03652058025972271, 0.4710820997517285, 0.8268941990105074, 0.03105084800597452], 0.0005670758628640047, 0.9546129326324247, 0.0005413379524736703
# 20:49:36 done sampling a new configuration.
# 20:49:36 HBMASTER: schedule new run for iteration 0
# 20:49:36 HBMASTER: trying submitting job (0, 0, 18) to dispatcher
# 20:49:36 HBMASTER: submitting job (0, 0, 18) to dispatcher
# 20:49:36 DISPATCHER: trying to submit job (0, 0, 18)
# 20:49:36 DISPATCHER: trying to notify the job_runner thread.
# 20:49:36 HBMASTER: job (0, 0, 18) submitted to dispatcher
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:36 DISPATCHER: starting job (0, 0, 18) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 DISPATCHER: job (0, 0, 18) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 WORKER: start processing job (0, 0, 18)
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:36 WORKER: args: ()
# 20:49:36 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 87, 'learning_rate': 0.005734970763120193, 'max_dropout': 0.0025711697433429825, 'max_units': 70.81987150669337, 'momentum': 0.5192630687790384, 'num_layers': 5, 'weight_decay': 0.0031147742921173926}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# 20:49:36 WORKER: done with job (0, 0, 18), trying to register it.
# 20:49:36 WORKER: registered result for job (0, 0, 18) with dispatcher
# 20:49:36 DISPATCHER: job (0, 0, 18) finished
# 20:49:36 DISPATCHER: register_result: lock acquired
# 20:49:36 DISPATCHER: job (0, 0, 18) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:36 job_id: (0, 0, 18)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 87, 'learning_rate': 0.005734970763120193, 'max_dropout': 0.0025711697433429825, 'max_units': 70.81987150669337, 'momentum': 0.5192630687790384, 'num_layers': 5, 'weight_decay': 0.0031147742921173926}, 'budget': 1.9259259259259258, 'working_directory': '.'}
# result: {'loss': -85.17120361328125, 'info': 'empty'}
# exception: None
#
# 20:49:36 job_callback for (0, 0, 18) started
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 job_callback for (0, 0, 18) got condition
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:36 done building a new model for budget 1.925926 based on 9/16 split
# Best loss for this budget:-90.247368
#
#
#
#
#
# 20:49:36 HBMASTER: Trying to run another job!
# 20:49:36 job_callback for (0, 0, 18) finished
# 20:49:36 start sampling a new configuration.
# 20:49:36 done sampling a new configuration.
# 20:49:36 HBMASTER: schedule new run for iteration 0
# 20:49:36 HBMASTER: trying submitting job (0, 0, 19) to dispatcher
# 20:49:36 HBMASTER: submitting job (0, 0, 19) to dispatcher
# 20:49:36 DISPATCHER: trying to submit job (0, 0, 19)
# 20:49:36 DISPATCHER: trying to notify the job_runner thread.
# 20:49:36 HBMASTER: job (0, 0, 19) submitted to dispatcher
# 20:49:36 DISPATCHER: Trying to submit another job.
# 20:49:36 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:36 DISPATCHER: starting job (0, 0, 19) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 DISPATCHER: job (0, 0, 19) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:36 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:36 WORKER: start processing job (0, 0, 19)
# 20:49:36 WORKER: args: ()
# ...
# 20:49:37 WORKER: done with job (0, 0, 23), trying to register it.
# 20:49:37 WORKER: registered result for job (0, 0, 23) with dispatcher
# 20:49:37 DISPATCHER: job (0, 0, 23) finished
# 20:49:37 DISPATCHER: register_result: lock acquired
# 20:49:37 DISPATCHER: job (0, 0, 23) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:37 job_id: (0, 0, 23)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.00029885953292362895, 'max_dropout': 0.19724576046703363, 'max_units': 65.5551215184368, 'momentum': 0.6125812448431202, 'num_layers': 5, 'weight_decay': 0.05347769087790378}, 'budget': 5.777777777777778, 'working_directory': '.'}
# result: {'loss': -95.02798461914062, 'info': 'empty'}
# exception: None
#
# 20:49:37 job_callback for (0, 0, 23) started
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 job_callback for (0, 0, 23) got condition
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:37 Only 7 run(s) for budget 5.777778 available, need more than 10 -> can't build model!
# 20:49:37 HBMASTER: Trying to run another job!
# 20:49:37 job_callback for (0, 0, 23) finished
# 20:49:37 HBMASTER: schedule new run for iteration 0
# 20:49:37 HBMASTER: trying submitting job (0, 0, 25) to dispatcher
# 20:49:37 HBMASTER: submitting job (0, 0, 25) to dispatcher
# 20:49:37 DISPATCHER: trying to submit job (0, 0, 25)
# 20:49:37 DISPATCHER: trying to notify the job_runner thread.
# 20:49:37 HBMASTER: job (0, 0, 25) submitted to dispatcher
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:37 DISPATCHER: starting job (0, 0, 25) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 DISPATCHER: job (0, 0, 25) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:37 WORKER: start processing job (0, 0, 25)
# 20:49:37 WORKER: args: ()
# 20:49:37 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 28, 'learning_rate': 0.06873675143113013, 'max_dropout': 0.21598397050104023, 'max_units': 68.15073076048655, 'momentum': 0.5616876877863817, 'num_layers': 5, 'weight_decay': 0.024825777105671968}, 'budget': 5.777777777777778, 'working_directory': '.'}
# 20:49:37 WORKER: done with job (0, 0, 25), trying to register it.
# 20:49:37 WORKER: registered result for job (0, 0, 25) with dispatcher
# 20:49:37 DISPATCHER: job (0, 0, 25) finished
# 20:49:37 DISPATCHER: register_result: lock acquired
# 20:49:37 DISPATCHER: job (0, 0, 25) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:37 job_id: (0, 0, 25)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 28, 'learning_rate': 0.06873675143113013, 'max_dropout': 0.21598397050104023, 'max_units': 68.15073076048655, 'momentum': 0.5616876877863817, 'num_layers': 5, 'weight_decay': 0.024825777105671968}, 'budget': 5.777777777777778, 'working_directory': '.'}
# result: {'loss': -94.30986022949219, 'info': 'empty'}
# exception: None
#
# 20:49:37 job_callback for (0, 0, 25) started
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 job_callback for (0, 0, 25) got condition
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:37 Only 8 run(s) for budget 5.777778 available, need more than 10 -> can't build model!
# 20:49:37 HBMASTER: Trying to run another job!
# 20:49:37 job_callback for (0, 0, 25) finished
# 20:49:37 HBMASTER: schedule new run for iteration 0
# 20:49:37 HBMASTER: trying submitting job (0, 0, 26) to dispatcher
# 20:49:37 HBMASTER: submitting job (0, 0, 26) to dispatcher
# 20:49:37 DISPATCHER: trying to submit job (0, 0, 26)
# 20:49:37 DISPATCHER: trying to notify the job_runner thread.
# 20:49:37 HBMASTER: job (0, 0, 26) submitted to dispatcher
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:37 DISPATCHER: starting job (0, 0, 26) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 DISPATCHER: job (0, 0, 26) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 WORKER: start processing job (0, 0, 26)
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:37 WORKER: args: ()
# 20:49:37 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 65, 'learning_rate': 0.003166988111149794, 'max_dropout': 0.2806709417455714, 'max_units': 186.705955960559, 'momentum': 0.630420075250819, 'num_layers': 5, 'weight_decay': 0.009300681832600426}, 'budget': 5.777777777777778, 'working_directory': '.'}
# 20:49:37 WORKER: done with job (0, 0, 26), trying to register it.
# 20:49:37 WORKER: registered result for job (0, 0, 26) with dispatcher
# 20:49:37 DISPATCHER: job (0, 0, 26) finished
# 20:49:37 DISPATCHER: register_result: lock acquired
# 20:49:37 DISPATCHER: job (0, 0, 26) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:37 job_id: (0, 0, 26)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 65, 'learning_rate': 0.003166988111149794, 'max_dropout': 0.2806709417455714, 'max_units': 186.705955960559, 'momentum': 0.630420075250819, 'num_layers': 5, 'weight_decay': 0.009300681832600426}, 'budget': 5.777777777777778, 'working_directory': '.'}
# result: {'loss': -93.39196014404297, 'info': 'empty'}
# exception: None
#
# 20:49:37 job_callback for (0, 0, 26) started
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 job_callback for (0, 0, 26) got condition
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:37 HBMASTER: Trying to run another job!
# 20:49:37 job_callback for (0, 0, 26) finished
# 20:49:37 ITERATION: Advancing config (0, 0, 16) to next budget 17.333333
# 20:49:37 ITERATION: Advancing config (0, 0, 22) to next budget 17.333333
# 20:49:37 ITERATION: Advancing config (0, 0, 23) to next budget 17.333333
# 20:49:37 HBMASTER: schedule new run for iteration 0
# 20:49:37 HBMASTER: trying submitting job (0, 0, 16) to dispatcher
# 20:49:37 HBMASTER: submitting job (0, 0, 16) to dispatcher
# 20:49:37 DISPATCHER: trying to submit job (0, 0, 16)
# 20:49:37 DISPATCHER: trying to notify the job_runner thread.
# 20:49:37 HBMASTER: job (0, 0, 16) submitted to dispatcher
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:37 DISPATCHER: starting job (0, 0, 16) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 DISPATCHER: job (0, 0, 16) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 WORKER: start processing job (0, 0, 16)
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:37 WORKER: args: ()
# 20:49:37 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.0621136801775151, 'max_dropout': 0.6721466528329146, 'max_units': 821.9641742662092, 'momentum': 0.6493487959873308, 'num_layers': 5, 'weight_decay': 0.04679336780314606}, 'budget': 17.333333333333332, 'working_directory': '.'}
# 20:49:37 WORKER: done with job (0, 0, 16), trying to register it.
# 20:49:37 WORKER: registered result for job (0, 0, 16) with dispatcher
# 20:49:37 DISPATCHER: job (0, 0, 16) finished
# 20:49:37 DISPATCHER: register_result: lock acquired
# 20:49:37 DISPATCHER: job (0, 0, 16) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:37 job_id: (0, 0, 16)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.0621136801775151, 'max_dropout': 0.6721466528329146, 'max_units': 821.9641742662092, 'momentum': 0.6493487959873308, 'num_layers': 5, 'weight_decay': 0.04679336780314606}, 'budget': 17.333333333333332, 'working_directory': '.'}
# result: {'loss': -94.20868682861328, 'info': 'empty'}
# exception: None
#
# 20:49:37 job_callback for (0, 0, 16) started
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 job_callback for (0, 0, 16) got condition
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:37 Only 1 run(s) for budget 17.333333 available, need more than 10 -> can't build model!
# 20:49:37 HBMASTER: Trying to run another job!
# 20:49:37 job_callback for (0, 0, 16) finished
# 20:49:37 HBMASTER: schedule new run for iteration 0
# 20:49:37 HBMASTER: trying submitting job (0, 0, 22) to dispatcher
# 20:49:37 HBMASTER: submitting job (0, 0, 22) to dispatcher
# 20:49:37 DISPATCHER: trying to submit job (0, 0, 22)
# 20:49:37 DISPATCHER: trying to notify the job_runner thread.
# 20:49:37 HBMASTER: job (0, 0, 22) submitted to dispatcher
# 20:49:37 DISPATCHER: Trying to submit another job.
# 20:49:37 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:37 DISPATCHER: starting job (0, 0, 22) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 DISPATCHER: job (0, 0, 22) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:37 WORKER: start processing job (0, 0, 22)
# 20:49:37 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:37 WORKER: args: ()
# 20:49:37 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 34, 'learning_rate': 0.020516887229563185, 'max_dropout': 0.2631625196046725, 'max_units': 274.99575120920446, 'momentum': 0.9868245594684214, 'num_layers': 5, 'weight_decay': 0.00683309415048856}, 'budget': 17.333333333333332, 'working_directory': '.'}
# 20:49:38 WORKER: done with job (0, 0, 22), trying to register it.
# 20:49:38 WORKER: registered result for job (0, 0, 22) with dispatcher
# 20:49:38 DISPATCHER: job (0, 0, 22) finished
# 20:49:38 DISPATCHER: register_result: lock acquired
# 20:49:38 DISPATCHER: job (0, 0, 22) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:38 job_id: (0, 0, 22)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 34, 'learning_rate': 0.020516887229563185, 'max_dropout': 0.2631625196046725, 'max_units': 274.99575120920446, 'momentum': 0.9868245594684214, 'num_layers': 5, 'weight_decay': 0.00683309415048856}, 'budget': 17.333333333333332, 'working_directory': '.'}
# result: {'loss': -96.07862091064453, 'info': 'empty'}
# exception: None
#
# 20:49:38 job_callback for (0, 0, 22) started
# 20:49:38 DISPATCHER: Trying to submit another job.
# 20:49:38 job_callback for (0, 0, 22) got condition
# 20:49:38 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:38 Only 2 run(s) for budget 17.333333 available, need more than 10 -> can't build model!
# 20:49:38 HBMASTER: Trying to run another job!
# 20:49:38 job_callback for (0, 0, 22) finished
# 20:49:38 HBMASTER: schedule new run for iteration 0
# 20:49:38 HBMASTER: trying submitting job (0, 0, 23) to dispatcher
# 20:49:38 HBMASTER: submitting job (0, 0, 23) to dispatcher
# 20:49:38 DISPATCHER: trying to submit job (0, 0, 23)
# 20:49:38 DISPATCHER: trying to notify the job_runner thread.
# 20:49:38 HBMASTER: job (0, 0, 23) submitted to dispatcher
# 20:49:38 DISPATCHER: Trying to submit another job.
# 20:49:38 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:38 DISPATCHER: starting job (0, 0, 23) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:38 DISPATCHER: job (0, 0, 23) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:38 WORKER: start processing job (0, 0, 23)
# 20:49:38 WORKER: args: ()
# 20:49:38 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:38 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.00029885953292362895, 'max_dropout': 0.19724576046703363, 'max_units': 65.5551215184368, 'momentum': 0.6125812448431202, 'num_layers': 5, 'weight_decay': 0.05347769087790378}, 'budget': 17.333333333333332, 'working_directory': '.'}
# 20:49:38 WORKER: done with job (0, 0, 23), trying to register it.
# 20:49:38 WORKER: registered result for job (0, 0, 23) with dispatcher
# 20:49:38 DISPATCHER: job (0, 0, 23) finished
# 20:49:38 DISPATCHER: register_result: lock acquired
# 20:49:38 DISPATCHER: job (0, 0, 23) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:38 job_id: (0, 0, 23)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 19, 'learning_rate': 0.00029885953292362895, 'max_dropout': 0.19724576046703363, 'max_units': 65.5551215184368, 'momentum': 0.6125812448431202, 'num_layers': 5, 'weight_decay': 0.05347769087790378}, 'budget': 17.333333333333332, 'working_directory': '.'}
# result: {'loss': -95.8232421875, 'info': 'empty'}
# exception: None
#
# 20:49:38 job_callback for (0, 0, 23) started
# 20:49:38 DISPATCHER: Trying to submit another job.
# 20:49:38 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:38 job_callback for (0, 0, 23) got condition
# 20:49:38 Only 3 run(s) for budget 17.333333 available, need more than 10 -> can't build model!
# 20:49:38 HBMASTER: Trying to run another job!
# 20:49:38 job_callback for (0, 0, 23) finished
# 20:49:38 ITERATION: Advancing config (0, 0, 22) to next budget 52.000000
# 20:49:38 HBMASTER: schedule new run for iteration 0
# 20:49:38 HBMASTER: trying submitting job (0, 0, 22) to dispatcher
# 20:49:38 HBMASTER: submitting job (0, 0, 22) to dispatcher
# 20:49:38 DISPATCHER: trying to submit job (0, 0, 22)
# 20:49:38 DISPATCHER: trying to notify the job_runner thread.
# 20:49:38 HBMASTER: job (0, 0, 22) submitted to dispatcher
# 20:49:38 DISPATCHER: Trying to submit another job.
# 20:49:38 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 20:49:38 DISPATCHER: starting job (0, 0, 22) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:38 DISPATCHER: job (0, 0, 22) dispatched on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344
# 20:49:38 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 20:49:38 WORKER: start processing job (0, 0, 22)
# 20:49:38 WORKER: args: ()
# 20:49:38 WORKER: kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 34, 'learning_rate': 0.020516887229563185, 'max_dropout': 0.2631625196046725, 'max_units': 274.99575120920446, 'momentum': 0.9868245594684214, 'num_layers': 5, 'weight_decay': 0.00683309415048856}, 'budget': 52.0, 'working_directory': '.'}
# 20:49:38 WORKER: done with job (0, 0, 22), trying to register it.
# 20:49:38 WORKER: registered result for job (0, 0, 22) with dispatcher
# 20:49:38 DISPATCHER: job (0, 0, 22) finished
# 20:49:38 DISPATCHER: register_result: lock acquired
# 20:49:38 DISPATCHER: job (0, 0, 22) on hpbandster.run_lcbench.worker.flo-x380.13581139977482281344 finished
# 20:49:38 job_id: (0, 0, 22)
# kwargs: {'config': {'OpenML_task_id': '3945', 'batch_size': 34, 'learning_rate': 0.020516887229563185, 'max_dropout': 0.2631625196046725, 'max_units': 274.99575120920446, 'momentum': 0.9868245594684214, 'num_layers': 5, 'weight_decay': 0.00683309415048856}, 'budget': 52.0, 'working_directory': '.'}
# result: {'loss': -96.92133331298828, 'info': 'empty'}
# exception: None
#
# 20:49:38 job_callback for (0, 0, 22) started
# 20:49:38 DISPATCHER: Trying to submit another job.
# 20:49:38 job_callback for (0, 0, 22) got condition
# 20:49:38 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 20:49:38 Only 1 run(s) for budget 52.000000 available, need more than 10 -> can't build model!
# 20:49:38 HBMASTER: Trying to run another job!
# 20:49:38 job_callback for (0, 0, 22) finished
# 20:49:38 HBMASTER: shutdown initiated, shutdown_workers = True
# 20:49:38 WORKER: shutting down now!
# 20:49:38 DISPATCHER: Dispatcher shutting down
# 20:49:38 DISPATCHER: Trying to submit another job.
# 20:49:38 DISPATCHER: job_runner shutting down
# 20:49:38 DISPATCHER: discover_workers shutting down
# 20:49:38 DISPATCHER: 'discover_worker' thread exited
# 20:49:38 DISPATCHER: 'job_runner' thread exited
# 20:49:38 DISPATCHER: shut down complete

# %% [markdown]
# Then we obtain the final results:

# %%
id2config = res.get_id2config_mapping()
id2config
# Out:
# {(0,
#   0,
#   0): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 475,
#    'learning_rate': 0.000279421845934996,
#    'max_dropout': 0.23277220802293364,
#    'max_units': 564.7617170743333,
#    'momentum': 0.28984493464511285,
#    'num_layers': 3,
#    'weight_decay': 0.08149013793334492}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   1): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 56,
#    'learning_rate': 0.006354512231197386,
#    'max_dropout': 0.53899351576789,
#    'max_units': 760.0387687665543,
#    'momentum': 0.9524552152326227,
#    'num_layers': 1,
#    'weight_decay': 0.014299983728636233}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   2): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 470,
#    'learning_rate': 0.054473558440077924,
#    'max_dropout': 0.7775565406704537,
#    'max_units': 877.9389562040402,
#    'momentum': 0.20871034235326025,
#    'num_layers': 1,
#    'weight_decay': 0.09301422668185681}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   3): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 107,
#    'learning_rate': 0.0008056685300095102,
#    'max_dropout': 0.6274292282744589,
#    'max_units': 313.29716079334656,
#    'momentum': 0.9547624615852874,
#    'num_layers': 4,
#    'weight_decay': 0.06927593294123785}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   4): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 107,
#    'learning_rate': 0.023759716613041697,
#    'max_dropout': 0.48796545419258286,
#    'max_units': 1015.3394832852503,
#    'momentum': 0.21920889883414185,
#    'num_layers': 3,
#    'weight_decay': 0.07525760547087604}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   5): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 38,
#    'learning_rate': 0.02740096278714067,
#    'max_dropout': 0.3117686181947872,
#    'max_units': 85.93326642988048,
#    'momentum': 0.91203473173557,
#    'num_layers': 1,
#    'weight_decay': 0.009653138036987183}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   6): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 178,
#    'learning_rate': 0.0036082742387284566,
#    'max_dropout': 0.8683862619706104,
#    'max_units': 73.30774499129984,
#    'momentum': 0.61144320171166,
#    'num_layers': 2,
#    'weight_decay': 0.03665315022053044}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   7): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 37,
#    'learning_rate': 0.0017057941756880518,
#    'max_dropout': 0.2944339409301566,
#    'max_units': 789.224718474469,
#    'momentum': 0.2512190464451524,
#    'num_layers': 2,
#    'weight_decay': 0.03696088552919684}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   8): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 60,
#    'learning_rate': 0.001476187203077695,
#    'max_dropout': 0.8410221316682499,
#    'max_units': 76.66865411198056,
#    'momentum': 0.5198854203560104,
#    'num_layers': 4,
#    'weight_decay': 0.06073803972957833}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   9): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 32,
#    'learning_rate': 0.002214603706032655,
#    'max_dropout': 0.5086992057264205,
#    'max_units': 88.57850791827076,
#    'momentum': 0.6403074434260884,
#    'num_layers': 5,
#    'weight_decay': 0.012816561379753523}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   10): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 177,
#    'learning_rate': 0.057437511966709674,
#    'max_dropout': 0.22954115201665692,
#    'max_units': 904.4787930506377,
#    'momentum': 0.2644376325733805,
#    'num_layers': 3,
#    'weight_decay': 0.03920370604017777}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   11): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 47,
#    'learning_rate': 0.0015700567569372414,
#    'max_dropout': 0.8581368374164389,
#    'max_units': 88.90522272429436,
#    'momentum': 0.6549488289926071,
#    'num_layers': 4,
#    'weight_decay': 0.013022608179727954}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   12): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 61,
#    'learning_rate': 0.0015064272555883043,
#    'max_dropout': 0.6323022686449326,
#    'max_units': 674.6319986695589,
#    'momentum': 0.7910702281500807,
#    'num_layers': 1,
#    'weight_decay': 0.04951487195483898}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   13): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 512,
#    'learning_rate': 0.0016498091380771458,
#    'max_dropout': 0.5396042938049899,
#    'max_units': 84.91367883532084,
#    'momentum': 0.35399083498210604,
#    'num_layers': 4,
#    'weight_decay': 0.09480577382148775}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   14): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 110,
#    'learning_rate': 0.03156520213590733,
#    'max_dropout': 0.15672883032679918,
#    'max_units': 281.31927448719534,
#    'momentum': 0.7125991123090649,
#    'num_layers': 1,
#    'weight_decay': 0.08829546149767076}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   15): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 316,
#    'learning_rate': 0.00033084169555737527,
#    'max_dropout': 0.36527654834607304,
#    'max_units': 290.8730954226177,
#    'momentum': 0.5470828298850363,
#    'num_layers': 1,
#    'weight_decay': 0.09440025839674766}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   16): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 19,
#    'learning_rate': 0.0621136801775151,
#    'max_dropout': 0.6721466528329146,
#    'max_units': 821.9641742662092,
#    'momentum': 0.6493487959873308,
#    'num_layers': 5,
#    'weight_decay': 0.04679336780314606}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   17): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 19,
#    'learning_rate': 0.02900417954390053,
#    'max_dropout': 0.5570228883121834,
#    'max_units': 470.78713650589003,
#    'momentum': 0.29739682673947965,
#    'num_layers': 1,
#    'weight_decay': 0.024829031497879243}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   18): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 87,
#    'learning_rate': 0.005734970763120193,
#    'max_dropout': 0.0025711697433429825,
#    'max_units': 70.81987150669337,
#    'momentum': 0.5192630687790384,
#    'num_layers': 5,
#    'weight_decay': 0.0031147742921173926}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   19): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 19,
#    'learning_rate': 0.0001416175788688995,
#    'max_dropout': 0.9224201023182139,
#    'max_units': 726.0070760464868,
#    'momentum': 0.1052215525293919,
#    'num_layers': 4,
#    'weight_decay': 0.0911414500573017}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   20): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 40,
#    'learning_rate': 0.00019715541241678512,
#    'max_dropout': 0.34043243039030346,
#    'max_units': 105.24486358458552,
#    'momentum': 0.1535866975984302,
#    'num_layers': 5,
#    'weight_decay': 0.08939237002665686}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   21): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 16,
#    'learning_rate': 0.0958893303962502,
#    'max_dropout': 0.7484994317497824,
#    'max_units': 937.4927821217709,
#    'momentum': 0.1602079418779419,
#    'num_layers': 1,
#    'weight_decay': 0.04633648324422067}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   22): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 34,
#    'learning_rate': 0.020516887229563185,
#    'max_dropout': 0.2631625196046725,
#    'max_units': 274.99575120920446,
#    'momentum': 0.9868245594684214,
#    'num_layers': 5,
#    'weight_decay': 0.00683309415048856}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   23): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 19,
#    'learning_rate': 0.00029885953292362895,
#    'max_dropout': 0.19724576046703363,
#    'max_units': 65.5551215184368,
#    'momentum': 0.6125812448431202,
#    'num_layers': 5,
#    'weight_decay': 0.05347769087790378}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   24): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 51,
#    'learning_rate': 0.001909405058564662,
#    'max_dropout': 0.7727956839735597,
#    'max_units': 291.2739689195257,
#    'momentum': 0.6772796427022922,
#    'num_layers': 3,
#    'weight_decay': 0.06944554254969797}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   25): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 28,
#    'learning_rate': 0.06873675143113013,
#    'max_dropout': 0.21598397050104023,
#    'max_units': 68.15073076048655,
#    'momentum': 0.5616876877863817,
#    'num_layers': 5,
#    'weight_decay': 0.024825777105671968}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   26): {'config': {'OpenML_task_id': '3945',
#    'batch_size': 65,
#    'learning_rate': 0.003166988111149794,
#    'max_dropout': 0.2806709417455714,
#    'max_units': 186.705955960559,
#    'momentum': 0.630420075250819,
#    'num_layers': 5,
#    'weight_decay': 0.009300681832600426}, 'config_info': {'model_based_pick': True}}}

# %%
incumbent = res.get_incumbent_id()
incumbent
# Out:
# (0, 0, 22)

# %%
print("Best found configuration:", id2config[incumbent]["config"])
print("A total of %i unique configurations where sampled." % len(id2config.keys()))
print("A total of %i runs where executed." % len(res.get_all_runs()))
print("Total budget corresponds to %.1f full function evaluations."%(sum([r.budget for r in res.get_all_runs()])/1))
# Out:
# Best found configuration: {'OpenML_task_id': '3945', 'batch_size': 34, 'learning_rate': 0.020516887229563185, 'max_dropout': 0.2631625196046725, 'max_units': 274.99575120920446, 'momentum': 0.9868245594684214, 'num_layers': 5, 'weight_decay': 0.00683309415048856}
# A total of 27 unique configurations where sampled.
# A total of 40 runs where executed.
# Total budget corresponds to 208.0 full function evaluations.
